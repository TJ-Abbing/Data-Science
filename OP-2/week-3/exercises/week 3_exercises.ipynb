# %% [markdown]
# # Week 3 Extra Exercise

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## About Dataset

# %% [markdown]
# The dataset includes the following columns:
#
# - PassengerId: A unique identifier for each passenger.
# - Survived: This column indicates whether a passenger survived (1) or did not survive (0).
# - Pclass (Ticket class): A proxy for socio-economic status, with 1 being the highest class and 3 the lowest.
# - Name: The name of the passenger.
# - Sex: The gender of the passenger.
# - Age: The age of the passenger. (Note: There might be missing values in this column.)
# - SibSp: The number of siblings or spouses the passenger had aboard the Titanic.
# - Parch: The number of parents or children the passenger had aboard the Titanic.
# - Ticket: The ticket number.
# - Fare: The amount of money the passenger paid for the ticket.
# - Cabin: The Cabin number
# - Embarked: The Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %% [markdown]
# ### Load the dataset

# %%
# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Dataset overview with info methd

# %%
# TODO
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Exercise 1: Handling Null Values

# %% [markdown]
# - Find the number of null values in the 'Age' and 'Embarked' columns.
# - Fill the null values in the 'Age' column with the mean age.
# - Remove rows with null values in the 'Embarked' column.

# %%
# Finding the Number of Null Values

# TODO
# Out:
# Number of null values in 'Age': 177
# Number of null values in 'Embarked': 2

# %%
# Handling Null Values

# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ### Exercise 2: Removing Duplicates

# %% [markdown]
# - Check for and display any duplicate rows in the dataset.
# - Remove duplicate rows.
#
# - NOTE: If we don't have any duplication in the original dataset, we will have the same number of rows after using the drop duplicate method.

# %%
# Removing Duplicates

# TODO
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ### Exercise 3: Sorting and Filtering Data

# %% [markdown]
# - Sort the dataset based on the 'Pclass' column in ascending order.
# - Filter rows where the 'Fare' column is greater than 50.

# %%
# Sorting and Filtering

# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 445          446         1       1
# 310          311         1       1
# 309          310         1       1
# 307          308         1       1
# 306          307         1       1
# ..           ...       ...     ...
# 378          379         0       3
# 379          380         0       3
# 381          382         1       3
# 368          369         1       3
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 445                          Dodge, Master. Washington    male   4.000000
# 310                     Hays, Miss. Margaret Bechstein  female  24.000000
# 309                     Francatelli, Miss. Laura Mabel  female  30.000000
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.000000
# 306                            Fleming, Miss. Margaret  female  29.699118
# ..                                                 ...     ...        ...
# ...

# %%
# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 27            28         0       1
# 31            32         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 6                              McCarthy, Mr. Timothy J    male  54.000000
# 27                      Fortune, Mr. Charles Alexander    male  19.000000
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  29.699118
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ### Exercise 4: Grouping and Aggregating Information

# %% [markdown]
# - Group the dataset by the 'Pclass' column.
# - Calculate the average age for each class.

# %%
# Grouping and Aggregating

# TODO
# Out:
# Pclass
# 1    36.927073
# 2    29.866958
# 3    26.403259
# Name: Age, dtype: float64

# %% [markdown]
# ### Exercise 5: Creating a New Feature Using the apply Function

# %% [markdown]
# #### Feature 1: FamilySize from 'SibSp' and 'Parch'

# %% [markdown]
# - Define a function that takes a row as an argument and returns the sum of 'SibSp' and 'Parch' plus 1.
# - Apply this function to the dataset using the apply function to create the 'FamilySize' feature.

# %%
# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# #### Feature 2: Family Size Category

# %% [markdown]
# Create a category based on family size.
#
# - size <= 3 is 'Small'
# - 3 < size <= 6 is 'Medium'
# - else 'Large'

# %%
# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# #### Feature 3: Title from Name

# %% [markdown]
# - Extract the title (Mr., Mrs., etc.) from the 'Name' column.
#
# Tip: You need to use split and strip methods from the string class. Pay close attention to understanding how Names are composed and that each part of the name separated

# %%
# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# TODO
# Out:
# Title
# Mr              517
# Miss            181
# Mrs             124
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: count, dtype: int64

# %% [markdown]
# #### Feature 4: Fare Category

# %% [markdown]
# Categorize fares into different ranges:
#
# - fare_bins = [0, 20, 50, 100, float('inf')] # I could use a big number but float('inf') acts as an unbounded upper value for comparison
# - fare_labels = ['Low', 'Medium', 'High', 'Very High']

# %%
# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# #### Feature 5: Age Group

# %% [markdown]
# Categorize ages into different groups:
# - age_bins = [0, 18, 30, 50, float('inf')]
# - age_labels = ['0-18', '19-30', '31-50', '51+']

# %%
# TODO
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...
